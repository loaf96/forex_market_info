# %%
import pandas as pd
import numpy as np
import time
import re

# %%
# FIRST TIME DATA FILE WAS BROUGHT IN... LATER TURNED INTO read_time function below
#
nine_tine = pd.read_csv('D2019.csv', encoding='utf-8', delimiter=';', header=None)
nine_tine.head()
nine_tine = nine_tine.rename(columns={0:'date', 1:'time', 2:'loca', 3:'exp_vol', 4:'event', 5:'pred_acc', 6:'unit_used', 7:'act_data', 8:'forc_data', 9:'prev_data'})
loca_few = pd.DataFrame(sorted(nine_tine.set_index('loca').groupby('loca')))

# %%
loca_few[1].iloc[0]
# Out:
#                                         date      time  \
# loca
# Australia                         2019/01/02   0:30:00
# Australia                         2019/01/06  16:30:00
# Australia                         2019/01/07   1:30:00
# Australia                         2019/01/07  19:30:00
# Australia                         2019/01/07  19:30:00
# Australia                         2019/01/07  19:30:00
# Australia                         2019/01/07  19:30:00
# Australia                         2019/01/08  16:30:00
# Australia                         2019/01/08  19:30:00
# Australia                         2019/01/08  19:30:00
# Australia                         2019/01/10  16:30:00
# Australia                         2019/01/10  19:30:00
# Australia                         2019/01/13  19:00:00
# Australia                         2019/01/14   1:30:00
# Australia                         2019/01/15  18:30:00
# Australia                         2019/01/16  19:00:00
# Australia                         2019/01/16  19:30:00
# Australia                         2019/01/16  19:30:00
# Australia                         2019/01/20  19:00:00
# Australia                         2019/01/21   1:30:00
# Australia                         2019/01/22  18:30:00
# Australia                         2019/01/23  19:30:00
# Australia                         2019/01/23  19:30:00
# Australia                         2019/01/23  19:30:00
# Australia                         2019/01/23  19:30:00
# Australia                         2019/01/28   1:30:00
# Australia                         2019/01/28  19:30:00
# Australia                         2019/01/28  19:30:00
# Australia                         2019/01/29  19:30:00
# Australia                         2019/01/29  19:30:00
# ...                                      ...       ...
# Australia                         2019/07/02   5:30:00
# Australia                         2019/07/02  18:30:00
# Australia                         2019/07/02  19:00:00
# Australia                         2019/07/02  21:30:00
# Australia                         2019/07/02  21:30:00
# Australia                         2019/07/02  21:30:00
# Australia                         2019/07/02  21:30:00
# Australia                         2019/07/02  21:30:00
# Australia                         2019/07/02  21:30:00
# Australia                         2019/07/03  21:30:00
# Australia                         2019/07/04  18:30:00
# Australia                         2019/07/07  21:30:00
# Australia                         2019/07/08  15:30:00
# Australia                         2019/07/08  21:30:00
# Australia                         2019/07/08  21:30:00
# Australia                         2019/07/09   1:30:00
# Australia                         2019/07/09  20:30:00
# Australia                         2019/07/10  21:00:00
# Australia                         2019/07/10  21:30:00
# Australia                         2019/07/11   9:10:00
# Australia                         2019/07/12  15:30:00
# Australia                         2019/07/15   1:30:00
# Australia                         2019/07/15  21:30:00
# Australia                         2019/07/16  20:30:00
# Australia                         2019/07/17  21:30:00
# Australia                         2019/07/17  21:30:00
# Australia                         2019/07/17  21:30:00
# Australia                         2019/07/17  21:30:00
# Australia                         2019/07/17  21:30:00
# Australia                         2019/07/19  15:30:00
#
#                                                            exp_vol  \
# loca
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         High Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         High Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         High Volatility Expected
# Australia                         Moderate Volatility Expected
# ...                                                            ...
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         High Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         High Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         High Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Low Volatility Expected
# Australia                         Moderate Volatility Expected
# Australia                         Moderate Volatility Expected
#
#                                                                               event  \
# loca
# Australia                         Commodity Prices                              ...
# Australia                         AIG Manufacturing Index                       ...
# Australia                         Investing.com AUD/USD Index                   ...
# Australia                         ANZ Job Advertisements                        ...
# Australia                         Exports                                       ...
# Australia                         Imports                                       ...
# Australia                         Trade Balance                                 ...
# Australia                         AIG Services Index                            ...
# Australia                         Building Approvals                            ...
# Australia                         Private House Approvals                       ...
# Australia                         AIG Construction Index                        ...
# Australia                         Retail Sales                                  ...
# Australia                         MI Inflation Gauge                            ...
# Australia                         Investing.com AUD/USD Index                   ...
# Australia                         Westpac Consumer Sentiment                    ...
# Australia                         MI Inflation Expectations                     ...
# Australia                         Home Loans                                    ...
# Australia                         Invest Housing Finance                        ...
# Australia                         HIA New Home Sales                            ...
# Australia                         Investing.com AUD/USD Index                   ...
# Australia                         MI Leading Index                              ...
# Australia                         Employment Change                             ...
# Australia                         Full Employment Change                        ...
# Australia                         Participation Rate                            ...
# Australia                         Unemployment Rate                             ...
# Australia                         Investing.com AUD/USD Index                   ...
# Australia                         NAB Business Confidence                       ...
# Australia                         NAB Business Survey                           ...
# Australia                         CPI                                           ...
# Australia                         CPI                                           ...
# ...                                                                             ...
# Australia                         RBA Governor Lowe Speaks                      ...
# Australia                         AIG Services Index                            ...
# Australia                         Services PMI                                  ...
# Australia                         Building Approvals                            ...
# Australia                         Exports                                       ...
# Australia                         Imports                                       ...
# Australia                         Private House Approvals                       ...
# Australia                         RBA Chart Pack Release                        ...
# Australia                         Trade Balance                                 ...
# Australia                         Retail Sales                                  ...
# Australia                         AIG Construction Index                        ...
# Australia                         ANZ Job Advertisements                        ...
# Australia                         CFTC AUD speculative net positions            ...
# Australia                         NAB Business Confidence                       ...
# Australia                         NAB Business Survey                           ...
# Australia                         Investing.com AUD/USD Index                   ...
# Australia                         Westpac Consumer Sentiment                    ...
# Australia                         MI Inflation Expectations                     ...
# Australia                         Home Loans                                    ...
# Australia                         RBA Assist Gov Debelle Speaks                 ...
# Australia                         CFTC AUD speculative net positions            ...
# Australia                         Investing.com AUD/USD Index                   ...
# Australia                         RBA Meeting Minutes                           ...
# Australia                         MI Leading Index                              ...
# Australia                         Employment Change                             ...
# Australia                         Full Employment Change                        ...
# Australia                         NAB Quarterly Business Confidence             ...
# Australia                         Participation Rate                            ...
# Australia                         Unemployment Rate                             ...
# Australia                         CFTC AUD speculative net positions            ...
#
#                                                           pred_acc unit_used  \
# loca
# Australia                                                      NaN        %
# Australia                                                      NaN       NaN
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                         Worse Than Expected                    B
# Australia                                                      NaN       NaN
# Australia                         Worse Than Expected                     %
# Australia                                                      NaN        %
# Australia                                                      NaN       NaN
# Australia                         Better Than Expected                    %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                         Better Than Expected                    %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                         Better Than Expected                   K
# Australia                                                      NaN       K
# Australia                         Worse Than Expected                     %
# Australia                         Better Than Expected                    %
# Australia                                                      NaN        %
# Australia                                                      NaN       NaN
# Australia                                                      NaN       NaN
# Australia                         Better Than Expected                    %
# Australia                         Better Than Expected                    %
# ...                                                            ...       ...
# Australia                                                      NaN       NaN
# Australia                                                      NaN       NaN
# Australia                         Worse Than Expected                    NaN
# Australia                         Better Than Expected                    %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN       NaN
# Australia                         Better Than Expected                   B
# Australia                         Worse Than Expected                     %
# Australia                                                      NaN       NaN
# Australia                                                      NaN        %
# Australia                                                      NaN       K
# Australia                         In Line with Expectation               NaN
# Australia                                                      NaN       NaN
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                                                      NaN        %
# Australia                         Better Than Expected                    %
# Australia                                                      NaN       NaN
# Australia                                                      NaN       K
# Australia                                                      NaN        %
# Australia                                                      NaN       NaN
# Australia                                                      NaN        %
# Australia                         Worse Than Expected                    K
# Australia                                                      NaN       K
# Australia                                                      NaN       NaN
# Australia                         In Line with Expectation                %
# Australia                         In Line with Expectation                %
# Australia                                                      NaN       K
#
#                                   act_data  forc_data  \
# loca
# Australia                            10.50        NaN
# Australia                            49.50        NaN
# Australia                            53.50        NaN
# Australia                             0.00        NaN
# Australia                             1.00        NaN
# Australia                             2.00        NaN
# Australia                             1.93       2.23
# Australia                            52.10        NaN
# Australia                            -9.10      -0.30
# Australia                            -2.60        NaN
# Australia                            42.60        NaN
# Australia                             0.40       0.30
# Australia                             0.40        NaN
# Australia                            50.20        NaN
# Australia                            -4.70        NaN
# Australia                             3.50        NaN
# Australia                            -0.90      -1.50
# Australia                            -4.50        NaN
# Australia                            -6.70        NaN
# Australia                            48.20        NaN
# Australia                            -0.20        NaN
# Australia                            21.60      16.50
# Australia                            -3.00        NaN
# Australia                            65.60      65.70
# Australia                             5.00       5.10
# Australia                            47.20        NaN
# Australia                             3.00        NaN
# Australia                             2.00        NaN
# Australia                             0.50       0.40
# Australia                             1.80       1.70
# ...                                    ...        ...
# Australia                              NaN        NaN
# Australia                            52.20        NaN
# Australia                            52.60      53.30
# Australia                             0.70       0.00
# Australia                             4.00        NaN
# Australia                             1.00        NaN
# Australia                            -0.30        NaN
# Australia                              NaN        NaN
# Australia                             5.75       5.25
# Australia                             0.10       0.20
# Australia                            43.00        NaN
# Australia                             4.60        NaN
# Australia                           -58.70        NaN
# Australia                             2.00       2.00
# Australia                             3.00        NaN
# Australia                            47.90        NaN
# Australia                            -4.10        NaN
# Australia                             3.20        NaN
# Australia                             0.00      -0.60
# Australia                              NaN        NaN
# Australia                           -54.00        NaN
# Australia                            43.90        NaN
# Australia                              NaN        NaN
# Australia                            -0.10        NaN
# Australia                             0.50       9.10
# Australia                            21.10        NaN
# Australia                             6.00        NaN
# Australia                            66.00      66.00
# Australia                             5.20       5.20
# Australia                           -52.60        NaN
#
#                                                                           prev_data
# loca
# Australia                                                          evised From 14.9
# Australia                                                                     51.30
# Australia                                                                     57.70
# Australia                                                          evised From -0.3
# Australia                                                                      1.00
# Australia                                                                      3.00
# Australia                                                                      2.32
# Australia                                                                     55.10
# Australia                                                                     -1.50
# Australia                                                                     -1.50
# Australia                                                                     44.50
# Australia                                                                      0.30
# Australia                                                                      0.00
# Australia                                                                     53.50
# Australia                                                                      0.10
# Australia                                                                      4.00
# Australia                                                           evised From 2.2
# Australia                                                                      0.60
# Australia                                                                      3.60
# Australia                                                                     50.20
# Australia                                                                     -0.10
# Australia                                                                     37.00
# Australia                                                                     -6.40
# Australia                                                                     65.70
# Australia                                                                      5.10
# Australia                                                                     48.20
# Australia                                                                      3.00
# Australia                                                                     11.00
# Australia                                                                      0.40
# Australia                                                                      1.90
# ...                                                                             ...
# Australia                                                                       NaN
# Australia                                                                      52.5
# Australia                         evised From 53.3>51.5                         ...
# Australia                                                                      -4.7
# Australia                                                                         2
# Australia                                                                         3
# Australia                                                                      -2.6
# Australia                                                                       NaN
# Australia                                                                     4.871
# Australia                                                                      -0.1
# Australia                                                                      40.4
# Australia                                                          evised From -8.4
# Australia                                                                     -66.3
# Australia                                                                         7
# Australia                                                                         1
# Australia                                                                      39.3
# Australia                                                                      -0.6
# Australia                                                                       3.3
# Australia                                                                      -1.2
# Australia                                                                       NaN
# Australia                                                                     -58.7
# Australia                                                                      47.9
# Australia                                                                       NaN
# Australia                                                                      -0.1
# Australia                                                                      42.3
# Australia                                                                       2.4
# Australia                                                                        -1
# Australia                                                                        66
# Australia                                                                       5.2
# Australia                                                                       -54
#
# [361 rows x 9 columns]

# %%
# brings in the csv file and puts it into a dataframe that allows for more practical uses as well as for setting up 
# the file to be able to be exported
def read_time(df_loc):
    df = pd.read_csv(df_loc, encoding='utf-8', delimiter=';', header=None)
    df = df.rename(columns={0:'date', 1:'time', 2:'loca', 3:'exp_vol', 4:'event', 5:'pred_acc', 6:'unit_used', 7:'act_data', 8:'forc_data', 9:'prev_data'})
    da_df = pd.DataFrame(sorted(df.set_index('loca').groupby('loca')))
    return da_df

# %%
poo = loca_few[1].iloc[1]
poop = poo.reset_index()
poop['loca'].iloc[1].strip(' ')
# Out:
# 'Brazil'

# %%
auzzy_land = list(loca_few[0].values)
real_auzzy_land = auzzy_land[0]
auzzy_land.index(real_auzzy_land)
# Out:
# 0

# %%
def fuck_dux(mf_df):
    auzzy_land = list(mf_df[0].values)
    outbk_stk = [x for x in auzzy_land]
    for house in outbk_stk:
        isdank = mf_df[1].iloc[auzzy_land.index(house)]
        filet = house.strip(' ')
        isdank.to_csv('cutlery/' + filet + '.csv')
        print('whats my mutha_fuckin name????????')
    next
    print('areeeee you readyyyyyyyyyy')
    return

# %%
fuck_dux(loca_few)
# Out:
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# whats my mutha_fuckin name????????
# areeeee you readyyyyyyyyyy
