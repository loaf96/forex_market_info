# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from math import pi

# %%
o_path = 'Data/eurusd_hour.csv'
my_path = 'Data/eurusd_minute.csv'
where_art = 'Data/exchange_rates.csv'
dis_data = pd.read_csv(my_path)
dat_data = pd.read_csv(o_path, delimiter=';', header=None)
which_path = pd.read_csv(where_art)

# %%
which_data = which_path.dropna(how='any')

# %%
shmoke = which_data.iloc[4::].set_index('Series Description')
shmoke.head()
# Out:
#                    SPOT EXCHANGE RATE - EURO AREA   \
# Series Description
# 1999-01-04                                  1.1812
# 1999-01-05                                  1.1760
# 1999-01-06                                  1.1636
# 1999-01-07                                  1.1672
# 1999-01-08                                  1.1554
#
#                    UNITED KINGDOM -- SPOT EXCHANGE RATE, US$/POUND (1/RXI_N.B.UK)  \
# Series Description
# 1999-01-04                                                     1.6581
# 1999-01-05                                                     1.6566
# 1999-01-06                                                     1.6547
# 1999-01-07                                                     1.6495
# 1999-01-08                                                     1.6405
#
#                    SPOT EXCHANGE RATE - BRAZIL   \
# Series Description
# 1999-01-04                               1.2074
# 1999-01-05                               1.2075
# ...

# %%
baba = shmoke.T

def money_time(which):
    b = baba.iloc[which]
    c = []
    for x in b:
        if str(x) != 'ND':
            c.append(x)
        else:
            None
        next
    e = [float(x) for x in c]
    f = [(x - abs(sum(e)/len(e))) for x in e]
    return f

# %%
lmno = [money_time(1)], [money_time(2)], [money_time(3)], [money_time(4)], [money_time(5)], [money_time(6)]

# %%
# plt.plot(money_time(1))
plt.plot(money_time(2))
plt.plot(money_time(3))
# plt.plot(money_time(4))
# plt.plot(money_time(5))
# plt.plot(money_time(6))
# plt.plot(baba.iloc[1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dat_data = dat_data.columns(col_names={0:'date', 1:'time', 2:'location', 3:'exp_vol', 4:'event', 5:'exp_eval'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-96095561834f> in <module>
# ----> 1 dat_data = dat_data.columns(col_names='l')
#
# TypeError: 'Int64Index' object is not callable
